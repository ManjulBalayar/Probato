# %%
import pandas as pd

# %%
state = pd.read_excel('Task Statements.xlsx')
state.head()
# Out:
#   O*NET-SOC Code             Title  Task ID  \
# 0     11-1011.00  Chief Executives     8823
# 1     11-1011.00  Chief Executives     8824
# 2     11-1011.00  Chief Executives     8827
# 3     11-1011.00  Chief Executives     8826
# 4     11-1011.00  Chief Executives     8834
#
#                                                 Task Task Type  \
# 0  Direct or coordinate an organization's financi...      Core
# 1  Confer with board members, organization offici...      Core
# 2  Prepare budgets for approval, including those ...      Core
# 3  Direct, plan, or implement policies, objective...      Core
# 4  Prepare or present reports concerning activiti...      Core
#
#    Incumbents Responding     Date Domain Source
# 0                   95.0  08/2023     Incumbent
# 1                   95.0  08/2023     Incumbent
# 2                   95.0  08/2023     Incumbent
# 3                   94.0  08/2023     Incumbent
# 4                   95.0  08/2023     Incumbent

# %%
ratings = pd.read_excel('Task Ratings.xlsx')
ratings.head()
# Out:
#   O*NET-SOC Code             Title  Task ID  \
# 0     11-1011.00  Chief Executives     8823
# 1     11-1011.00  Chief Executives     8823
# 2     11-1011.00  Chief Executives     8823
# 3     11-1011.00  Chief Executives     8823
# 4     11-1011.00  Chief Executives     8823
#
#                                                 Task Scale ID  \
# 0  Direct or coordinate an organization's financi...       FT
# 1  Direct or coordinate an organization's financi...       FT
# 2  Direct or coordinate an organization's financi...       FT
# 3  Direct or coordinate an organization's financi...       FT
# 4  Direct or coordinate an organization's financi...       FT
#
#                            Scale Name  Category  Data Value     N  \
# 0  Frequency of Task (Categories 1-7)       1.0        5.92  76.0
# 1  Frequency of Task (Categories 1-7)       2.0       15.98  76.0
# 2  Frequency of Task (Categories 1-7)       3.0       29.68  76.0
# ...

# %%
categories = pd.read_excel('Task Categories.xlsx')
categories.head()
# Out:
#   Scale ID                          Scale Name  Category Category Description
# 0       FT  Frequency of Task (Categories 1-7)         1       Yearly or less
# 1       FT  Frequency of Task (Categories 1-7)         2     More than yearly
# 2       FT  Frequency of Task (Categories 1-7)         3    More than monthly
# 3       FT  Frequency of Task (Categories 1-7)         4     More than weekly
# 4       FT  Frequency of Task (Categories 1-7)         5                Daily

# %%
state['Title'].nunique()
# Out:
# 923

# %%
state['Task Type'].nunique()
# Out:
# 2

# %%
state['Task'].nunique()
# Out:
# 18008

# %% [markdown]
# ## 18,000 different types of tasks. There is no data value, instead, it checks if the task is either a 'Core' or 'Supplemental' task. In order for it to be a core task, the task must be relevant ≥ 67% and have an importance rating of 3.0

# %%
state.shape
# Out:
# (19281, 8)

# %%
ratings.shape
# Out:
# (161847, 15)

# %% [markdown]
# ## I will for now only utilize the task ratings since it has the same tasks but also a data value for the 'Frequency of tasks' from 1-7 and 'Relevance' from 0-100. For the 'Frequency of tasks' there is a scale ID and a 'Category' column for them. Each task is repeated 7 times for each category and then given a data value for them.

# %%
ratings['Attribute Type'] = 'Task Ratings'

# %%
ratings.dtypes
# Out:
# O*NET-SOC Code         object
# Title                  object
# Task ID                 int64
# Task                   object
# Scale ID               object
# Scale Name             object
# Category              float64
# Data Value            float64
# N                     float64
# Standard Error        float64
# Lower CI Bound        float64
# Upper CI Bound        float64
# Recommend Suppress     object
# Date                   object
# Domain Source          object
# Attribute Type         object
# dtype: object

# %%
columnReorder = ['O*NET-SOC Code', 'Title', 'Attribute Type', 'Task ID', 'Task', 'Scale Name', 'Data Value']
ratings = ratings[columnReorder]
ratings.head()
# Out:
#   O*NET-SOC Code             Title Attribute Type  Task ID  \
# 0     11-1011.00  Chief Executives   Task Ratings     8823
# 1     11-1011.00  Chief Executives   Task Ratings     8823
# 2     11-1011.00  Chief Executives   Task Ratings     8823
# 3     11-1011.00  Chief Executives   Task Ratings     8823
# 4     11-1011.00  Chief Executives   Task Ratings     8823
#
#                                                 Task  \
# 0  Direct or coordinate an organization's financi...
# 1  Direct or coordinate an organization's financi...
# 2  Direct or coordinate an organization's financi...
# 3  Direct or coordinate an organization's financi...
# 4  Direct or coordinate an organization's financi...
#
#                            Scale Name  Data Value
# 0  Frequency of Task (Categories 1-7)        5.92
# 1  Frequency of Task (Categories 1-7)       15.98
# 2  Frequency of Task (Categories 1-7)       29.68
# 3  Frequency of Task (Categories 1-7)       21.18
# ...

# %%
ratings
# Out:
#        O*NET-SOC Code                              Title Attribute Type  \
# 0          11-1011.00                   Chief Executives   Task Ratings
# 1          11-1011.00                   Chief Executives   Task Ratings
# 2          11-1011.00                   Chief Executives   Task Ratings
# 3          11-1011.00                   Chief Executives   Task Ratings
# 4          11-1011.00                   Chief Executives   Task Ratings
# ...               ...                                ...            ...
# 161842     53-7121.00  Tank Car, Truck, and Ship Loaders   Task Ratings
# 161843     53-7121.00  Tank Car, Truck, and Ship Loaders   Task Ratings
# 161844     53-7121.00  Tank Car, Truck, and Ship Loaders   Task Ratings
# 161845     53-7121.00  Tank Car, Truck, and Ship Loaders   Task Ratings
# 161846     53-7121.00  Tank Car, Truck, and Ship Loaders   Task Ratings
#
#         Task ID                                               Task  \
# ...

# %%
ratings = ratings.loc[(ratings['Scale Name'] == 'Importance') | (ratings['Scale Name'] == 'Relevance of Task')]
ratings.head()
# Out:
#    O*NET-SOC Code             Title Attribute Type  Task ID  \
# 7      11-1011.00  Chief Executives   Task Ratings     8823
# 8      11-1011.00  Chief Executives   Task Ratings     8823
# 16     11-1011.00  Chief Executives   Task Ratings     8824
# 17     11-1011.00  Chief Executives   Task Ratings     8824
# 25     11-1011.00  Chief Executives   Task Ratings     8827
#
#                                                  Task         Scale Name  \
# 7   Direct or coordinate an organization's financi...         Importance
# 8   Direct or coordinate an organization's financi...  Relevance of Task
# 16  Confer with board members, organization offici...         Importance
# 17  Confer with board members, organization offici...  Relevance of Task
# 25  Prepare budgets for approval, including those ...         Importance
#
#     Data Value
# 7         4.52
# 8        74.44
# 16        4.32
# 17       81.71
# 25        4.30

# %%
ratings.shape
# Out:
# (35966, 7)

# %%
ratings.loc[(ratings['Title'] == 'Chief Executives') & (ratings['Task ID'] == 8838)]
# Out:
#     O*NET-SOC Code             Title Attribute Type  Task ID  \
# 241     11-1011.00  Chief Executives   Task Ratings     8838
# 242     11-1011.00  Chief Executives   Task Ratings     8838
#
#                                                   Task         Scale Name  \
# 241  Direct non-merchandising departments, such as ...         Importance
# 242  Direct non-merchandising departments, such as ...  Relevance of Task
#
#      Data Value
# 241        3.78
# 242       56.74

# %%
ratings.loc[ratings['Title'] == 'Chief Executives']
# Out:
#     O*NET-SOC Code             Title Attribute Type  Task ID  \
# 7       11-1011.00  Chief Executives   Task Ratings     8823
# 8       11-1011.00  Chief Executives   Task Ratings     8823
# 16      11-1011.00  Chief Executives   Task Ratings     8824
# 17      11-1011.00  Chief Executives   Task Ratings     8824
# 25      11-1011.00  Chief Executives   Task Ratings     8827
# ..             ...               ...            ...      ...
# 260     11-1011.00  Chief Executives   Task Ratings     8848
# 268     11-1011.00  Chief Executives   Task Ratings     8846
# 269     11-1011.00  Chief Executives   Task Ratings     8846
# 277     11-1011.00  Chief Executives   Task Ratings     8852
# 278     11-1011.00  Chief Executives   Task Ratings     8852
#
#                                                   Task         Scale Name  \
# 7    Direct or coordinate an organization's financi...         Importance
# 8    Direct or coordinate an organization's financi...  Relevance of Task
# ...
