# %%
import pandas as pd

# %%
tech = pd.read_excel('Technology Skills.xlsx')
tech.head()
# Out:
#   O*NET-SOC Code             Title  \
# 0     11-1011.00  Chief Executives
# 1     11-1011.00  Chief Executives
# 2     11-1011.00  Chief Executives
# 3     11-1011.00  Chief Executives
# 4     11-1011.00  Chief Executives
#
#                                          Example  Commodity Code  \
# 0                                  Adobe Acrobat        43232202
# 1                                AdSense Tracker        43232306
# 2                                 Atlassian JIRA        43232201
# 3                    Blackbaud The Raiser's Edge        43232303
# 4  ComputerEase construction accounting software        43231601
#
#                                  Commodity Title Hot Technology In Demand
# 0                   Document management software              Y         N
# 1    Data base user interface and query software              N         N
# 2                      Content workflow software              Y         N
# ...

# %%
tools = pd.read_excel('Tools Used.xlsx')
tools.head()
# Out:
#   O*NET-SOC Code             Title                          Example  \
# 0     11-1011.00  Chief Executives               10-key calculators
# 1     11-1011.00  Chief Executives                Desktop computers
# 2     11-1011.00  Chief Executives                 Laptop computers
# 3     11-1011.00  Chief Executives               Personal computers
# 4     11-1011.00  Chief Executives  Personal digital assistants PDA
#
#    Commodity Code                                Commodity Title
# 0        44101809                             Desktop calculator
# 1        43211507                              Desktop computers
# 2        43211503                             Notebook computers
# 3        43211508                             Personal computers
# 4        43211504  Personal digital assistant PDAs or organizers

# %%
tech.tail()
# Out:
#       O*NET-SOC Code                              Title  \
# 32465     53-7121.00  Tank Car, Truck, and Ship Loaders
# 32466     53-7121.00  Tank Car, Truck, and Ship Loaders
# 32467     53-7121.00  Tank Car, Truck, and Ship Loaders
# 32468     53-7121.00  Tank Car, Truck, and Ship Loaders
# 32469     53-7121.00  Tank Car, Truck, and Ship Loaders
#
#                                Example  Commodity Code  \
# 32465                            Linux        43233004
# 32466                  Microsoft Excel        43232110
# 32467        Microsoft Office software        43231513
# 32468                     SAP software        43231602
# 32469  Warehouse management system WMS        43231506
#
#                                          Commodity Title Hot Technology  \
# 32465                          Operating system software              Y
# 32466                               Spreadsheet software              Y
# 32467                              Office suite software              Y
# ...

# %%
tools.tail()
# Out:
#       O*NET-SOC Code                              Title  \
# 41645     53-7121.00  Tank Car, Truck, and Ship Loaders
# 41646     53-7121.00  Tank Car, Truck, and Ship Loaders
# 41647     53-7121.00  Tank Car, Truck, and Ship Loaders
# 41648     53-7121.00  Tank Car, Truck, and Ship Loaders
# 41649     53-7121.00  Tank Car, Truck, and Ship Loaders
#
#                          Example  Commodity Code    Commodity Title
# 41645              Stock pickers        24101605  Loading equipment
# 41646           Tablet computers        43211509   Tablet computers
# 41647   Walk behind pallet jacks        24101505      Pallet trucks
# 41648        Warehouse forklifts        24101603          Forklifts
# 41649  Wheeled front end loaders        22101501  Front end loaders

# %%
ceotools = tools.loc[tools['Title'] == 'Chief Executives']
ceotools
# Out:
#   O*NET-SOC Code             Title                                Example  \
# 0     11-1011.00  Chief Executives                     10-key calculators
# 1     11-1011.00  Chief Executives                      Desktop computers
# 2     11-1011.00  Chief Executives                       Laptop computers
# 3     11-1011.00  Chief Executives                     Personal computers
# 4     11-1011.00  Chief Executives        Personal digital assistants PDA
# 5     11-1011.00  Chief Executives                            Smartphones
# 6     11-1011.00  Chief Executives  Universal serial bus USB flash drives
#
#    Commodity Code                                Commodity Title
# 0        44101809                             Desktop calculator
# 1        43211507                              Desktop computers
# 2        43211503                             Notebook computers
# 3        43211508                             Personal computers
# ...

# %%
ceo = tech.loc[(tech['In Demand'] == 'Y') & (tech['Title'] == 'Chief Executives')]
ceo
# Out:
#    O*NET-SOC Code             Title                    Example  \
# 27     11-1011.00  Chief Executives            Microsoft Excel
# 29     11-1011.00  Chief Executives  Microsoft Office software
#
#     Commodity Code        Commodity Title Hot Technology In Demand
# 27        43232110   Spreadsheet software              Y         Y
# 29        43231513  Office suite software              Y         Y

# %%
tech.loc[tech['In Demand'] == 'Y']
# Out:
#       O*NET-SOC Code                                             Title  \
# 27        11-1011.00                                  Chief Executives
# 29        11-1011.00                                  Chief Executives
# 56        11-1011.03                     Chief Sustainability Officers
# 57        11-1011.03                     Chief Sustainability Officers
# 58        11-1011.03                     Chief Sustainability Officers
# ...              ...                                               ...
# 32417     53-7065.00                        Stockers and Order Fillers
# 32433     53-7071.00  Gas Compressor and Gas Pumping Station Operators
# 32434     53-7071.00  Gas Compressor and Gas Pumping Station Operators
# 32435     53-7071.00  Gas Compressor and Gas Pumping Station Operators
# 32450     53-7073.00                                  Wellhead Pumpers
#
#                             Example  Commodity Code  \
# 27                  Microsoft Excel        43232110
# ...

# %%
techColumns = ['O*NET-SOC Code', 'Title', 'Example', 'Hot Technology', 'In Demand']
tech = tech[techColumns]
tech.head()
# Out:
#   O*NET-SOC Code             Title  \
# 0     11-1011.00  Chief Executives
# 1     11-1011.00  Chief Executives
# 2     11-1011.00  Chief Executives
# 3     11-1011.00  Chief Executives
# 4     11-1011.00  Chief Executives
#
#                                          Example Hot Technology In Demand
# 0                                  Adobe Acrobat              Y         N
# 1                                AdSense Tracker              N         N
# 2                                 Atlassian JIRA              Y         N
# 3                    Blackbaud The Raiser's Edge              N         N
# 4  ComputerEase construction accounting software              N         N

# %%
toolsColumns = ['O*NET-SOC Code', 'Title', 'Example']
tools = tools[toolsColumns]
tools.head()
# Out:
#   O*NET-SOC Code             Title                          Example
# 0     11-1011.00  Chief Executives               10-key calculators
# 1     11-1011.00  Chief Executives                Desktop computers
# 2     11-1011.00  Chief Executives                 Laptop computers
# 3     11-1011.00  Chief Executives               Personal computers
# 4     11-1011.00  Chief Executives  Personal digital assistants PDA

# %%
tech.to_csv('TechSkills.csv', index=False)

# %%
tools.to_csv('Tools.csv', index=False)
