# %%
import pandas as pd

# %%
context = pd.read_excel('Work Context.xlsx')
context.head()
# Out:
#   O*NET-SOC Code             Title   Element ID     Element Name Scale ID  \
# 0     11-1011.00  Chief Executives  4.C.1.a.2.c  Public Speaking       CX
# 1     11-1011.00  Chief Executives  4.C.1.a.2.c  Public Speaking      CXP
# 2     11-1011.00  Chief Executives  4.C.1.a.2.c  Public Speaking      CXP
# 3     11-1011.00  Chief Executives  4.C.1.a.2.c  Public Speaking      CXP
# 4     11-1011.00  Chief Executives  4.C.1.a.2.c  Public Speaking      CXP
#
#                  Scale Name  Category  Data Value     N  Standard Error  \
# 0                   Context       NaN        3.07  37.0          0.2851
# 1  Context (Categories 1-5)       1.0        0.13  37.0          0.1370
# 2  Context (Categories 1-5)       2.0       39.49  37.0         11.0101
# 3  Context (Categories 1-5)       3.0       33.07  37.0          7.1359
# 4  Context (Categories 1-5)       4.0        7.79  37.0          4.3613
#
#    Lower CI Bound  Upper CI Bound Recommend Suppress  Not Relevant     Date  \
# ...

# %%
context.head(10)
# Out:
#   O*NET-SOC Code             Title   Element ID     Element Name Scale ID  \
# 0     11-1011.00  Chief Executives  4.C.1.a.2.c  Public Speaking       CX
# 1     11-1011.00  Chief Executives  4.C.1.a.2.c  Public Speaking      CXP
# 2     11-1011.00  Chief Executives  4.C.1.a.2.c  Public Speaking      CXP
# 3     11-1011.00  Chief Executives  4.C.1.a.2.c  Public Speaking      CXP
# 4     11-1011.00  Chief Executives  4.C.1.a.2.c  Public Speaking      CXP
# 5     11-1011.00  Chief Executives  4.C.1.a.2.c  Public Speaking      CXP
# 6     11-1011.00  Chief Executives  4.C.1.a.2.f        Telephone       CX
# 7     11-1011.00  Chief Executives  4.C.1.a.2.f        Telephone      CXP
# 8     11-1011.00  Chief Executives  4.C.1.a.2.f        Telephone      CXP
# 9     11-1011.00  Chief Executives  4.C.1.a.2.f        Telephone      CXP
#
#                  Scale Name  Category  Data Value     N  Standard Error  \
# 0                   Context       NaN        3.07  37.0          0.2851
# ...

# %%
context = context.loc[context['Scale ID'] == 'CX']
context.head(10)
# Out:
#    O*NET-SOC Code             Title   Element ID  \
# 0      11-1011.00  Chief Executives  4.C.1.a.2.c
# 6      11-1011.00  Chief Executives  4.C.1.a.2.f
# 12     11-1011.00  Chief Executives  4.C.1.a.2.h
# 18     11-1011.00  Chief Executives  4.C.1.a.2.j
# 24     11-1011.00  Chief Executives  4.C.1.a.2.l
# 30     11-1011.00  Chief Executives    4.C.1.a.4
# 36     11-1011.00  Chief Executives  4.C.1.b.1.e
# 42     11-1011.00  Chief Executives  4.C.1.b.1.f
# 48     11-1011.00  Chief Executives  4.C.1.b.1.g
# 54     11-1011.00  Chief Executives    4.C.1.c.1
#
#                                  Element Name Scale ID Scale Name  Category  \
# 0                             Public Speaking       CX    Context       NaN
# 6                                   Telephone       CX    Context       NaN
# 12                            Electronic Mail       CX    Context       NaN
# 18                          Letters and Memos       CX    Context       NaN
# ...

# %%
context['Attribute Type'] = 'Work Context'

# %%
contextCols = ['O*NET-SOC Code', 'Title', 'Attribute Type', 'Element ID', 'Element Name', 'Scale Name', 'Data Value']
context = context[contextCols]
context.head()
# Out:
#    O*NET-SOC Code             Title Attribute Type   Element ID  \
# 0      11-1011.00  Chief Executives   Work Context  4.C.1.a.2.c
# 6      11-1011.00  Chief Executives   Work Context  4.C.1.a.2.f
# 12     11-1011.00  Chief Executives   Work Context  4.C.1.a.2.h
# 18     11-1011.00  Chief Executives   Work Context  4.C.1.a.2.j
# 24     11-1011.00  Chief Executives   Work Context  4.C.1.a.2.l
#
#                 Element Name Scale Name  Data Value
# 0            Public Speaking    Context        3.07
# 6                  Telephone    Context        4.92
# 12           Electronic Mail    Context        4.97
# 18         Letters and Memos    Context        4.14
# 24  Face-to-Face Discussions    Context        4.90

# %%
context.to_csv('WorkCon.csv', index=False)

# %%
context.shape
# Out:
# (48015, 7)
