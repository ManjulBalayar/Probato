# %%
import pandas as pd

# %%
interest_df = pd.read_excel('Interests.xlsx')
interest_df.head(9)
# Out:
#   O*NET-SOC Code             Title Element ID                Element Name  \
# 0     11-1011.00  Chief Executives    1.B.1.a                   Realistic
# 1     11-1011.00  Chief Executives    1.B.1.b               Investigative
# 2     11-1011.00  Chief Executives    1.B.1.c                    Artistic
# 3     11-1011.00  Chief Executives    1.B.1.d                      Social
# 4     11-1011.00  Chief Executives    1.B.1.e                Enterprising
# 5     11-1011.00  Chief Executives    1.B.1.f                Conventional
# 6     11-1011.00  Chief Executives    1.B.1.g   First Interest High-Point
# 7     11-1011.00  Chief Executives    1.B.1.h  Second Interest High-Point
# 8     11-1011.00  Chief Executives    1.B.1.i   Third Interest High-Point
#
#   Scale ID                        Scale Name  Data Value     Date  \
# 0       OI            Occupational Interests        1.30  11/2023
# 1       OI            Occupational Interests        3.24  11/2023
# ...

# %%
interest_df.shape
# Out:
# (8307, 9)

# %%
interest_df['Title'].nunique()
# Out:
# 923

# %%
interest_df.drop(interest_df[interest_df['Element Name'] == 'First Interest High-Point'].index, inplace=True)
interest_df.drop(interest_df[interest_df['Element Name'] == 'Second Interest High-Point'].index, inplace=True)
interest_df.drop(interest_df[interest_df['Element Name'] == 'Third Interest High-Point'].index, inplace=True)

# %%
interest_df.shape
# Out:
# (5538, 9)

# %%
interest_df['Attribute Type'] = 'Interest'

# %%
interest_df
# Out:
#      O*NET-SOC Code                              Title Element ID  \
# 0        11-1011.00                   Chief Executives    1.B.1.a
# 1        11-1011.00                   Chief Executives    1.B.1.b
# 2        11-1011.00                   Chief Executives    1.B.1.c
# 3        11-1011.00                   Chief Executives    1.B.1.d
# 4        11-1011.00                   Chief Executives    1.B.1.e
# ...             ...                                ...        ...
# 8299     53-7121.00  Tank Car, Truck, and Ship Loaders    1.B.1.b
# 8300     53-7121.00  Tank Car, Truck, and Ship Loaders    1.B.1.c
# 8301     53-7121.00  Tank Car, Truck, and Ship Loaders    1.B.1.d
# 8302     53-7121.00  Tank Car, Truck, and Ship Loaders    1.B.1.e
# 8303     53-7121.00  Tank Car, Truck, and Ship Loaders    1.B.1.f
#
#        Element Name Scale ID              Scale Name  Data Value     Date  \
# 0         Realistic       OI  Occupational Interests        1.30  11/2023
# ...

# %%
columnReorder = ['O*NET-SOC Code', 'Title', 'Attribute Type', 'Element ID', 'Element Name', 'Scale Name', 'Data Value']
interest_df = interest_df[columnReorder]
interest_df.head()
# Out:
#   O*NET-SOC Code             Title Attribute Type Element ID   Element Name  \
# 0     11-1011.00  Chief Executives       Interest    1.B.1.a      Realistic
# 1     11-1011.00  Chief Executives       Interest    1.B.1.b  Investigative
# 2     11-1011.00  Chief Executives       Interest    1.B.1.c       Artistic
# 3     11-1011.00  Chief Executives       Interest    1.B.1.d         Social
# 4     11-1011.00  Chief Executives       Interest    1.B.1.e   Enterprising
#
#                Scale Name  Data Value
# 0  Occupational Interests        1.30
# 1  Occupational Interests        3.24
# 2  Occupational Interests        2.08
# 3  Occupational Interests        3.52
# 4  Occupational Interests        6.88

# %%
interest_df.to_csv('Interests.csv')
