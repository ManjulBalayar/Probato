# %%
import pandas as pd

# %% [markdown]
# ## Datasets
#
# All of the following datasets below share the same format, the ones that aren't included are Tasks, Technology Skills, and Tools Used. Not sure how to utilize them yet.

# %%
#Knowledge, Skills, Abilities
ksa = pd.read_csv('KSA.csv')

#Education, Experience, Training
eet = pd.read_csv('EET.csv')

#Interests
interests = pd.read_csv('Interests.csv')

#Work Values & Styles
wvs = pd.read_csv('WV&S.csv')

#Work Activities
wac = pd.read_csv('WorkAct.csv')

#Work Context
con = pd.read_csv('WorkCon.csv')

# %% [markdown]
# ## Education, Experience, Training Format Change
#
# For Scale Name, there are 4 types:
# - Required Level Of Education (Categories 1-12)
# - Related Work Experience (Categories 1-11)
# - On-Site Or In-Plant Training (Categories 1-9)
# - On-The-Job Training (Categories 1-9)
#
# There are a total of 41 different categories. But let's breakdown each category. For 'Required Level of Education' which has 12 categories, it goes from highschool level to post-doctoral training. For 'Related Work Experience' which has 11 categories, it ranges from none to over 10 years. The 'On-site or In-Plant Training' has 9 categories and ranges from none to over 10 years. And finally for 'On-The-Job Training', it ranges from none or short demonstration to over 10 years.
#
# I need to somehow, condense all the different categories and get one value for each of them, but I am not sure how to sum up the values for each categories. I cannot just sum them all up because they will all just add up to 100. Each category has it's own unique data value, for example, if category = 1 which is High School Level for 'Required Level of Education' and the 'Data Value' is 0, that means for that position, 0% of people only have highschool level degree. And if the category = 8, which means masters or something, and the value is 45.91, it means 45.91% of people in that position have a required masters level education. Each category has it's own value, so then how do I get the best value to represent each of those categories.

# %% [markdown]
# ## EET Update
#
# Ok so I plan to keep the detailed categories. Why? I want a more accurate model, and it's not necessary that I get rid of those categories. More granularity could help with a more accurate recommendation. That being said, I need to simplify the UI for the user so that they don't get lost in the detail and the categories. Just keeping it simple and convinient for them.
#
# What I did instead was that I git rid of the 'Category' column for the eet df so that it follows the other datasets format. I turned the 'Scale Name' column to essentially become the 'Category' value since the 'Element Name' column is already the same as 'Scale Name'.

# %%
# Step 1: Create a new 'Scale Name' column with Category values
eet['New Scale Name'] = ' Category ' + eet['Category'].astype(str)

# Step 2: Drop the original 'Scale Name' and 'Category' columns
eet = eet.drop(columns=['Scale Name', 'Category'])

# Step 3: Rename 'New Scale Name' to 'Scale Name'
eet = eet.rename(columns={'New Scale Name': 'Scale Name'})

# %% [markdown]
# ## TO DO:
#
# Add 'Attribute Type' Column to EET, split them into 'Education', 'Experience', and 'Training' based on the 'Element Name' column as they correspond. For example 'Required Level of Education' would be turned into 'Education' category in the 'Attribute Type', 'Related Work Experience' would be 'Experience', and 'On-Site or In-Plant Training' & 'On-the-Job Training' would fall under 'Training' for 'Attribute Type'. So in total there would be three different attribute types.

# %%
eet
# Out:
#       O*NET-SOC Code                              Title Element ID  \
# 0         11-1011.00                   Chief Executives      2.D.1
# 1         11-1011.00                   Chief Executives      2.D.1
# 2         11-1011.00                   Chief Executives      2.D.1
# 3         11-1011.00                   Chief Executives      2.D.1
# 4         11-1011.00                   Chief Executives      2.D.1
# ...              ...                                ...        ...
# 34927     53-7121.00  Tank Car, Truck, and Ship Loaders      3.A.3
# 34928     53-7121.00  Tank Car, Truck, and Ship Loaders      3.A.3
# 34929     53-7121.00  Tank Car, Truck, and Ship Loaders      3.A.3
# 34930     53-7121.00  Tank Car, Truck, and Ship Loaders      3.A.3
# 34931     53-7121.00  Tank Car, Truck, and Ship Loaders      3.A.3
#
#                       Element Name  Data Value   Scale Name
# 0      Required Level of Education        0.00   Category 1
# 1      Required Level of Education        4.46   Category 2
# 2      Required Level of Education        0.00   Category 3
# 3      Required Level of Education        0.00   Category 4
# 4      Required Level of Education        5.15   Category 5
# ...                            ...         ...          ...
# 34927          On-the-Job Training       27.84   Category 5
# 34928          On-the-Job Training       12.27   Category 6
# 34929          On-the-Job Training        1.21   Category 7
# 34930          On-the-Job Training        1.57   Category 8
# 34931          On-the-Job Training        0.00   Category 9
#
# [34932 rows x 6 columns]

# %%
def get_attribute_type(element_name):
    if element_name == 'Required Level of Education':
        return 'Education'
    elif element_name == 'Related Work Experience':
        return 'Experience'
    elif element_name in ['On-Site or In-Plant Training', 'On-the-Job Training']:
        return 'Training'
    else:
        return 'Unknown'

eet['Attribute Type'] = eet['Element Name'].apply(get_attribute_type)
column_order = ['O*NET-SOC Code', 'Title', 'Attribute Type', 'Element ID', 'Element Name', 'Scale Name', 'Data Value']  # Add other columns as needed
eet = eet[column_order]
eet
# Out:
#       O*NET-SOC Code                              Title Attribute Type  \
# 0         11-1011.00                   Chief Executives      Education
# 1         11-1011.00                   Chief Executives      Education
# 2         11-1011.00                   Chief Executives      Education
# 3         11-1011.00                   Chief Executives      Education
# 4         11-1011.00                   Chief Executives      Education
# ...              ...                                ...            ...
# 34927     53-7121.00  Tank Car, Truck, and Ship Loaders       Training
# 34928     53-7121.00  Tank Car, Truck, and Ship Loaders       Training
# 34929     53-7121.00  Tank Car, Truck, and Ship Loaders       Training
# 34930     53-7121.00  Tank Car, Truck, and Ship Loaders       Training
# 34931     53-7121.00  Tank Car, Truck, and Ship Loaders       Training
#
#       Element ID                 Element Name   Scale Name  Data Value
# 0          2.D.1  Required Level of Education   Category 1        0.00
# 1          2.D.1  Required Level of Education   Category 2        4.46
# 2          2.D.1  Required Level of Education   Category 3        0.00
# 3          2.D.1  Required Level of Education   Category 4        0.00
# 4          2.D.1  Required Level of Education   Category 5        5.15
# ...          ...                          ...          ...         ...
# 34927      3.A.3          On-the-Job Training   Category 5       27.84
# 34928      3.A.3          On-the-Job Training   Category 6       12.27
# 34929      3.A.3          On-the-Job Training   Category 7        1.21
# 34930      3.A.3          On-the-Job Training   Category 8        1.57
# 34931      3.A.3          On-the-Job Training   Category 9        0.00
#
# [34932 rows x 7 columns]

# %% [markdown]
# ### Dropping auto-generated index

# %%
ksa.head()
# Out:
#   O*NET-SOC Code             Title Attribute Type Element ID  \
# 0     11-1011.00  Chief Executives      Knowledge    2.C.1.a
# 1     11-1011.00  Chief Executives      Knowledge    2.C.1.a
# 2     11-1011.00  Chief Executives      Knowledge    2.C.1.b
# 3     11-1011.00  Chief Executives      Knowledge    2.C.1.b
# 4     11-1011.00  Chief Executives      Knowledge    2.C.1.c
#
#                     Element Name  Scale Name  Data Value
# 0  Administration and Management  Importance        4.78
# 1  Administration and Management       Level        6.50
# 2                 Administrative  Importance        2.42
# 3                 Administrative       Level        2.69
# 4       Economics and Accounting  Importance        4.04

# %%
df = pd.concat([ksa, eet, interests, wvs, wac, con], ignore_index=True)
df
# Out:
#        O*NET-SOC Code                              Title Attribute Type  \
# 0          11-1011.00                   Chief Executives      Knowledge
# 1          11-1011.00                   Chief Executives      Knowledge
# 2          11-1011.00                   Chief Executives      Knowledge
# 3          11-1011.00                   Chief Executives      Knowledge
# 4          11-1011.00                   Chief Executives      Knowledge
# ...               ...                                ...            ...
# 391420     53-7121.00  Tank Car, Truck, and Ship Loaders   Work Context
# 391421     53-7121.00  Tank Car, Truck, and Ship Loaders   Work Context
# 391422     53-7121.00  Tank Car, Truck, and Ship Loaders   Work Context
# 391423     53-7121.00  Tank Car, Truck, and Ship Loaders   Work Context
# 391424     53-7121.00  Tank Car, Truck, and Ship Loaders   Work Context
#
#        Element ID                           Element Name  Scale Name  \
# 0         2.C.1.a          Administration and Management  Importance
# 1         2.C.1.a          Administration and Management       Level
# 2         2.C.1.b                         Administrative  Importance
# 3         2.C.1.b                         Administrative       Level
# 4         2.C.1.c               Economics and Accounting  Importance
# ...           ...                                    ...         ...
# 391420  4.C.3.b.7     Importance of Repeating Same Tasks     Context
# 391421  4.C.3.b.8    Structured versus Unstructured Work     Context
# 391422  4.C.3.c.1                   Level of Competition     Context
# 391423  4.C.3.d.1                          Time Pressure     Context
# 391424  4.C.3.d.3  Pace Determined by Speed of Equipment     Context
#
#         Data Value
# 0             4.78
# 1             6.50
# 2             2.42
# 3             2.69
# 4             4.04
# ...            ...
# 391420        4.45
# 391421        3.89
# 391422        2.97
# 391423        4.47
# 391424        3.56
#
# [391425 rows x 7 columns]

# %%
df
# Out:
#        O*NET-SOC Code                              Title Attribute Type  \
# 0          11-1011.00                   Chief Executives      Knowledge
# 1          11-1011.00                   Chief Executives      Knowledge
# 2          11-1011.00                   Chief Executives      Knowledge
# 3          11-1011.00                   Chief Executives      Knowledge
# 4          11-1011.00                   Chief Executives      Knowledge
# ...               ...                                ...            ...
# 391420     53-7121.00  Tank Car, Truck, and Ship Loaders   Work Context
# 391421     53-7121.00  Tank Car, Truck, and Ship Loaders   Work Context
# 391422     53-7121.00  Tank Car, Truck, and Ship Loaders   Work Context
# 391423     53-7121.00  Tank Car, Truck, and Ship Loaders   Work Context
# 391424     53-7121.00  Tank Car, Truck, and Ship Loaders   Work Context
#
#        Element ID                           Element Name  Scale Name  \
# 0         2.C.1.a          Administration and Management  Importance
# 1         2.C.1.a          Administration and Management       Level
# 2         2.C.1.b                         Administrative  Importance
# 3         2.C.1.b                         Administrative       Level
# 4         2.C.1.c               Economics and Accounting  Importance
# ...           ...                                    ...         ...
# 391420  4.C.3.b.7     Importance of Repeating Same Tasks     Context
# 391421  4.C.3.b.8    Structured versus Unstructured Work     Context
# 391422  4.C.3.c.1                   Level of Competition     Context
# 391423  4.C.3.d.1                          Time Pressure     Context
# 391424  4.C.3.d.3  Pace Determined by Speed of Equipment     Context
#
#         Data Value
# 0             4.78
# 1             6.50
# 2             2.42
# 3             2.69
# 4             4.04
# ...            ...
# 391420        4.45
# 391421        3.89
# 391422        2.97
# 391423        4.47
# 391424        3.56
#
# [391425 rows x 7 columns]

# %%
df['Attribute Type'].unique()
# Out:
# array(['Knowledge', 'Skill', 'Ability', 'Education', 'Experience',
#        'Training', 'Interest', 'Work Values', 'Work Styles',
#        'Work Activity', 'Work Context'], dtype=object)

# %%
eet
# Out:
#       O*NET-SOC Code                              Title Attribute Type  \
# 0         11-1011.00                   Chief Executives      Education
# 1         11-1011.00                   Chief Executives      Education
# 2         11-1011.00                   Chief Executives      Education
# 3         11-1011.00                   Chief Executives      Education
# 4         11-1011.00                   Chief Executives      Education
# ...              ...                                ...            ...
# 34927     53-7121.00  Tank Car, Truck, and Ship Loaders       Training
# 34928     53-7121.00  Tank Car, Truck, and Ship Loaders       Training
# 34929     53-7121.00  Tank Car, Truck, and Ship Loaders       Training
# 34930     53-7121.00  Tank Car, Truck, and Ship Loaders       Training
# 34931     53-7121.00  Tank Car, Truck, and Ship Loaders       Training
#
#       Element ID                 Element Name   Scale Name  Data Value
# 0          2.D.1  Required Level of Education   Category 1        0.00
# 1          2.D.1  Required Level of Education   Category 2        4.46
# 2          2.D.1  Required Level of Education   Category 3        0.00
# 3          2.D.1  Required Level of Education   Category 4        0.00
# 4          2.D.1  Required Level of Education   Category 5        5.15
# ...          ...                          ...          ...         ...
# 34927      3.A.3          On-the-Job Training   Category 5       27.84
# 34928      3.A.3          On-the-Job Training   Category 6       12.27
# 34929      3.A.3          On-the-Job Training   Category 7        1.21
# 34930      3.A.3          On-the-Job Training   Category 8        1.57
# 34931      3.A.3          On-the-Job Training   Category 9        0.00
#
# [34932 rows x 7 columns]

# %%
df.to_csv('model_dataset.csv', index=False)
