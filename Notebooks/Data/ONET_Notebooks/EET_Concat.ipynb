# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# /bin/bash: line 1: nvidia-smi: command not found

# %%
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 13.6 gigabytes of available RAM
#
# Not using a high-RAM runtime

# %%
import pandas as pd

# %%
eet_df = pd.read_excel('Education, Training, and Experience.xlsx')
eet_df.head()
# Out:
#   O*NET-SOC Code             Title Element ID                 Element Name  \
# 0     11-1011.00  Chief Executives      2.D.1  Required Level of Education
# 1     11-1011.00  Chief Executives      2.D.1  Required Level of Education
# 2     11-1011.00  Chief Executives      2.D.1  Required Level of Education
# 3     11-1011.00  Chief Executives      2.D.1  Required Level of Education
# 4     11-1011.00  Chief Executives      2.D.1  Required Level of Education
#
#   Scale ID                                     Scale Name  Category  \
# 0       RL  Required Level Of Education (Categories 1-12)       1.0
# 1       RL  Required Level Of Education (Categories 1-12)       2.0
# 2       RL  Required Level Of Education (Categories 1-12)       3.0
# 3       RL  Required Level Of Education (Categories 1-12)       4.0
# 4       RL  Required Level Of Education (Categories 1-12)       5.0
#
#    Data Value   N  Standard Error  Lower CI Bound  Upper CI Bound  \
# ...

# %%
job_zones = pd.read_excel('Job Zones.xlsx')
job_zones.head()
# Out:
#   O*NET-SOC Code                                Title  Job Zone     Date  \
# 0     11-1011.00                     Chief Executives         5  08/2023
# 1     11-1011.03        Chief Sustainability Officers         5  08/2021
# 2     11-1021.00      General and Operations Managers         4  08/2023
# 3     11-1031.00                          Legislators         4  06/2008
# 4     11-2011.00  Advertising and Promotions Managers         4  08/2018
#
#   Domain Source
# 0       Analyst
# 1       Analyst
# 2       Analyst
# 3       Analyst
# 4       Analyst

# %% [markdown]
# ## Won't include Job Zones dataset now for convenience of following same format. Plus the model might be able to pick this up later anyways.

# %%
columnsToKeep = ['O*NET-SOC Code', 'Title', 'Element ID', 'Element Name', 'Scale Name', 'Category', 'Data Value']
eet_df = eet_df[columnsToKeep]
eet_df.head(12)
# Out:
#    O*NET-SOC Code             Title Element ID                 Element Name  \
# 0      11-1011.00  Chief Executives      2.D.1  Required Level of Education
# 1      11-1011.00  Chief Executives      2.D.1  Required Level of Education
# 2      11-1011.00  Chief Executives      2.D.1  Required Level of Education
# 3      11-1011.00  Chief Executives      2.D.1  Required Level of Education
# 4      11-1011.00  Chief Executives      2.D.1  Required Level of Education
# 5      11-1011.00  Chief Executives      2.D.1  Required Level of Education
# 6      11-1011.00  Chief Executives      2.D.1  Required Level of Education
# 7      11-1011.00  Chief Executives      2.D.1  Required Level of Education
# 8      11-1011.00  Chief Executives      2.D.1  Required Level of Education
# 9      11-1011.00  Chief Executives      2.D.1  Required Level of Education
# 10     11-1011.00  Chief Executives      2.D.1  Required Level of Education
# ...

# %%
print('Unique Knowledge Types: ', eet_df['Element Name'].nunique())
# Out:
# Unique Knowledge Types:  6

# %% [markdown]
# ### There is 873 different types of positions on the KSA datasets but only 852 for this dataset. Going to have to be careful when merging them.

# %%
print('Number of unique positions: ', eet_df['Title'].nunique())
# Out:
# Number of unique positions:  852

# %%
print('Different Types of Positions:', eet_df['Element Name'].unique())
# Out:
# Different Types of Positions: ['Required Level of Education' 'Job-Related Professional Certification'
#  'Related Work Experience' 'On-Site or In-Plant Training'
#  'On-the-Job Training' 'Apprenticeship']

# %% [markdown]
# ## I think I will drop 'Apprenticeship' and 'Job-Related Professional Certification' since I don't know what they are and it also doens't have categories.

# %%
eet_df.loc[eet_df['Element Name'] == 'Apprenticeship']
# Out:
#       O*NET-SOC Code                                      Title Element ID  \
# 42        11-1011.00                           Chief Executives    3.A.4.a
# 85        11-1011.03              Chief Sustainability Officers    3.A.4.a
# 128       11-1021.00            General and Operations Managers    3.A.4.a
# 171       11-2011.00        Advertising and Promotions Managers    3.A.4.a
# 378       11-3031.00                         Financial Managers    3.A.4.a
# ...              ...                                        ...        ...
# 35462     53-7061.00         Cleaners of Vehicles and Equipment    3.A.4.a
# 35628     53-7064.00                Packers and Packagers, Hand    3.A.4.a
# 35671     53-7065.00                 Stockers and Order Fillers    3.A.4.a
# 35755     53-7072.00    Pump Operators, Except Wellhead Pumpers    3.A.4.a
# 35839     53-7081.00  Refuse and Recyclable Material Collectors    3.A.4.a
#
#          Element Name  Scale Name  Category  Data Value
# ...

# %%
eet_df.loc[eet_df['Element Name'] == 'Job-Related Professional Certification']
# Out:
#       O*NET-SOC Code                                      Title Element ID  \
# 12        11-1011.00                           Chief Executives    2.D.4.a
# 55        11-1011.03              Chief Sustainability Officers    2.D.4.a
# 98        11-1021.00            General and Operations Managers    2.D.4.a
# 141       11-2011.00        Advertising and Promotions Managers    2.D.4.a
# 348       11-3031.00                         Financial Managers    2.D.4.a
# ...              ...                                        ...        ...
# 35432     53-7061.00         Cleaners of Vehicles and Equipment    2.D.4.a
# 35598     53-7064.00                Packers and Packagers, Hand    2.D.4.a
# 35641     53-7065.00                 Stockers and Order Fillers    2.D.4.a
# 35725     53-7072.00    Pump Operators, Except Wellhead Pumpers    2.D.4.a
# 35809     53-7081.00  Refuse and Recyclable Material Collectors    2.D.4.a
#
# ...

# %%
eet_df.drop(eet_df[eet_df['Element Name'] == 'Apprenticeship'].index, inplace=True)
eet_df.loc[eet_df['Element Name'] == 'Apprenticeship']
# Out:
# Empty DataFrame
# Columns: [O*NET-SOC Code, Title, Element ID, Element Name, Scale Name, Category, Data Value]
# Index: []

# %%
eet_df.drop(eet_df[eet_df['Element Name'] == 'Job-Related Professional Certification'].index, inplace=True)
eet_df.loc[eet_df['Element Name'] == 'Job-Related Professional Certification']
# Out:
# Empty DataFrame
# Columns: [O*NET-SOC Code, Title, Element ID, Element Name, Scale Name, Category, Data Value]
# Index: []

# %%
eet_df
# Out:
#       O*NET-SOC Code                              Title Element ID  \
# 0         11-1011.00                   Chief Executives      2.D.1
# 1         11-1011.00                   Chief Executives      2.D.1
# 2         11-1011.00                   Chief Executives      2.D.1
# 3         11-1011.00                   Chief Executives      2.D.1
# 4         11-1011.00                   Chief Executives      2.D.1
# ...              ...                                ...        ...
# 35876     53-7121.00  Tank Car, Truck, and Ship Loaders      3.A.3
# 35877     53-7121.00  Tank Car, Truck, and Ship Loaders      3.A.3
# 35878     53-7121.00  Tank Car, Truck, and Ship Loaders      3.A.3
# 35879     53-7121.00  Tank Car, Truck, and Ship Loaders      3.A.3
# 35880     53-7121.00  Tank Car, Truck, and Ship Loaders      3.A.3
#
#                       Element Name  \
# 0      Required Level of Education
# 1      Required Level of Education
# 2      Required Level of Education
# ...

# %%
eet_df['Scale Name'].unique()
# Out:
# array(['Required Level Of Education (Categories 1-12)',
#        'Related Work Experience (Categories 1-11)',
#        'On-Site Or In-Plant Training (Categories 1-9)',
#        'On-The-Job Training (Categories 1-9)'], dtype=object)

# %%
eet_df['Element Name'].unique()
# Out:
# array(['Required Level of Education', 'Related Work Experience',
#        'On-Site or In-Plant Training', 'On-the-Job Training'],
#       dtype=object)

# %%
# Step 1: Create a new 'Scale Name' column with Category values
eet_df['New Scale Name'] = ' Category ' + eet_df['Category'].astype(str)

# Step 2: Drop the original 'Scale Name' and 'Category' columns
eet_df = eet_df.drop(columns=['Scale Name', 'Category'])

# Step 3: Rename 'New Scale Name' to 'Scale Name'
eet_df = eet_df.rename(columns={'New Scale Name': 'Scale Name'})

# Reorder columns if needed
column_order = ['O*NET-SOC Code', 'Title', 'Element Name', 'Scale Name', 'Data Value']
eet_df = eet_df[column_order]

# %%
eet_df
# Out:
#       O*NET-SOC Code                              Title  \
# 0         11-1011.00                   Chief Executives
# 1         11-1011.00                   Chief Executives
# 2         11-1011.00                   Chief Executives
# 3         11-1011.00                   Chief Executives
# 4         11-1011.00                   Chief Executives
# ...              ...                                ...
# 35876     53-7121.00  Tank Car, Truck, and Ship Loaders
# 35877     53-7121.00  Tank Car, Truck, and Ship Loaders
# 35878     53-7121.00  Tank Car, Truck, and Ship Loaders
# 35879     53-7121.00  Tank Car, Truck, and Ship Loaders
# 35880     53-7121.00  Tank Car, Truck, and Ship Loaders
#
#                       Element Name     Scale Name  Data Value
# 0      Required Level of Education   Category 1.0        0.00
# 1      Required Level of Education   Category 2.0        4.46
# 2      Required Level of Education   Category 3.0        0.00
# ...
